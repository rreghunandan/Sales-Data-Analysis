# %% [markdown]
# <a href="https://colab.research.google.com/github/rreghunandan/Sales-Data-Analysis/blob/main/GUVI_Data_Analysis_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --upgrade xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import plotly as py

# %%
df=pd.read_excel('/content/DataAnalystTask.xls')

# %%
df.head()
# Out:
#   User ID Product Code Payment Status Coupon code Lead Registered Time  \
# 0   user1     Product1      Initiated         NaN  2022-08-01 04:55:00
# 1   user2     Product2      Initiated         NaN  2022-08-01 04:46:00
# 2   user4     Product3      Initiated         NaN  2022-08-01 03:21:00
# 3   user6     Product3      Initiated         NaN  2022-08-01 00:56:00
# 4   user8     Product4      Initiated         NaN  2022-08-01 00:46:00
#
#   Sales Date  Source  Product Amount with GST Payment Mode Currency  Code  \
# 0 2022-07-31  Direct                   3999.0          NaN            INR
# 1 2022-07-31  Direct                    999.0          NaN            INR
# 2 2022-07-31  Direct                   1999.0          NaN            INR
# 3 2022-07-31  Direct                   1999.0          NaN            INR
# 4 2022-07-31  Direct                   2022.0          NaN            INR
#
#   Transaction Bank
# 0              NaN
# 1              NaN
# 2              NaN
# ...

# %%
df.shape # To check number of rows and columns
# Out:
# (9514, 11)

# %%
df.columns
# Out:
# Index(['User ID', 'Product Code', 'Payment Status', 'Coupon code',
#        'Lead Registered Time', 'Sales Date', 'Source',
#        'Product Amount with GST', 'Payment Mode', 'Currency  Code',
#        'Transaction Bank'],
#       dtype='object')

# %%
df.dtypes
# Out:
# User ID                            object
# Product Code                       object
# Payment Status                     object
# Coupon code                        object
# Lead Registered Time       datetime64[ns]
# Sales Date                 datetime64[ns]
# Source                             object
# Product Amount with GST           float64
# Payment Mode                       object
# Currency  Code                     object
# Transaction Bank                   object
# dtype: object

# %% [markdown]
# Here lead registered time and sales date is in Datetime,so not reqired to convert.

# %%
df.set_index('Sales Date',inplace =True)

# %%
df.head()
# Out:
#            User ID Product Code Payment Status Coupon code  \
# Sales Date
# 2022-07-31   user1     Product1      Initiated         NaN
# 2022-07-31   user2     Product2      Initiated         NaN
# 2022-07-31   user4     Product3      Initiated         NaN
# 2022-07-31   user6     Product3      Initiated         NaN
# 2022-07-31   user8     Product4      Initiated         NaN
#
#            Lead Registered Time  Source  Product Amount with GST Payment Mode  \
# Sales Date
# 2022-07-31  2022-08-01 04:55:00  Direct                   3999.0          NaN
# 2022-07-31  2022-08-01 04:46:00  Direct                    999.0          NaN
# 2022-07-31  2022-08-01 03:21:00  Direct                   1999.0          NaN
# 2022-07-31  2022-08-01 00:56:00  Direct                   1999.0          NaN
# 2022-07-31  2022-08-01 00:46:00  Direct                   2022.0          NaN
#
#            Currency  Code Transaction Bank
# Sales Date
# 2022-07-31            INR              NaN
# ...

# %%
df.describe()  # Statistical Summary
# Out:
#        Product Amount with GST
# count              9513.000000
# mean               1464.982533
# std                1277.535383
# min                   4.680000
# 25%                 499.000000
# 50%                1499.000000
# 75%                1999.000000
# max               29992.000000

# %%
df.isnull().sum() # To check null values
# Out:
# User ID                       0
# Product Code                  0
# Payment Status                0
# Coupon code                8852
# Lead Registered Time          0
# Source                        0
# Product Amount with GST       1
# Payment Mode               7784
# Currency  Code                0
# Transaction Bank           9422
# dtype: int64

# %% [markdown]
# Here coupon code ,payment mode and Transaction bank has null values and because its in a huge number the rows are dropped.

# %%
df.drop(["Coupon code","Payment Mode","Transaction Bank"],axis=1)
# Out:
#               User ID Product Code Payment Status Lead Registered Time  \
# Sales Date
# 2022-07-31      user1     Product1      Initiated  2022-08-01 04:55:00
# 2022-07-31      user2     Product2      Initiated  2022-08-01 04:46:00
# 2022-07-31      user4     Product3      Initiated  2022-08-01 03:21:00
# 2022-07-31      user6     Product3      Initiated  2022-08-01 00:56:00
# 2022-07-31      user8     Product4      Initiated  2022-08-01 00:46:00
# ...               ...          ...            ...                  ...
# 2022-06-01   user7253   Product105           paid  2022-06-01 14:46:00
# 2022-06-01   user7253   Product105           paid  2022-06-01 12:36:00
# 2022-06-01   user7253   Product105           paid  2022-06-01 12:31:00
# 2022-06-01  user10657     Product2           paid  2022-06-01 07:20:00
# 2022-06-21  user10658    Product10         refund  2022-05-28 06:21:00
#
#             Source  Product Amount with GST Currency  Code
# Sales Date
# ...
